# %%
##loading bmi csv file
import pandas as pd
data = pd.read_csv("/content/bmi.csv")
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
# Preprocess the data

# Replace yes and no with 1 and 0
data['Gender'].replace({'Male': 0, 'Female': 1},inplace = True)
data
# Out:
#      Gender  Height  Weight  Index
# 0         0     174      96      4
# 1         0     189      87      2
# 2         1     185     110      4
# 3         1     195     104      3
# 4         0     149      61      3
# ..      ...     ...     ...    ...
# 495       1     150     153      5
# 496       1     184     121      4
# 497       1     141     136      5
# 498       0     150      95      5
# 499       0     173     131      5
#
# [500 rows x 4 columns]

# %%
## prints the size of the dataframe ex:500 rows x 4 columns
df = data.dropna()
print("new shape:" ,df.shape)
# Out:
# new shape: (500, 4)

# %%
x = data[['Gender','Height','Weight']]
y = data.Index

# %%
## Splitting Our Data
## We split our data into training and test data to cross-validate our model.

## Here we will be using 80% training data and 20% test data. To split our data we must import train_test_split from the sklearn library. We also randomly-shuffle our data to prevent any bias problems. random_state = 42, keeps the shuffling algorithm the same, so we produce consistent results which are easier to evaluate.

from sklearn.datasets import load_iris
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 101)
x_train.shape
# Out:
# (400, 3)

# %%
## printing the list of columns

print(list(data.columns))
# Out:
# ['Gender', 'Height', 'Weight', 'Index']

# %%
## printing pairplt for the dataframe

import seaborn as sns

sns.pairplot(data[['Gender', 'Height', 'Weight', 'Index']])

# %%
data.columns
# Out:
# Index(['Gender', 'Height', 'Weight', 'Index'], dtype='object')

# %%
##We drop certain columns that we deem not necessary for the logistic regression process.

df_new = data.drop(data.columns[2],axis =1)

##The trimmed dataframe is saved to df_new, a new dataframe...

df_new
# Out:
#      Gender  Height  Index
# 0         0     174      4
# 1         0     189      2
# 2         1     185      4
# 3         1     195      3
# 4         0     149      3
# ..      ...     ...    ...
# 495       1     150      5
# 496       1     184      4
# 497       1     141      5
# 498       0     150      5
# 499       0     173      5
#
# [500 rows x 3 columns]

# %%
## LINEAR REGRESSION

## DATA:

#3 x(week)               y(sales in thounsands)
#-------------------------------------------------

# Linear regression formula--> y= a0+a1x

# a1 = ((mean(x*y))-(mean(x)*mean(y))/(mean(x^2)-mean(x)^2)

#a0 = mean(y)-a1*mean(x)

#  x        y          x^2          x*y
  # ---------------------------------------
  # 1         1.2         1         1.2
  # 2         1.8         4         3.6
  # 3         2.5         9         7.5
  # 4         3.2         16         12.8
  # 5         3.8         25         19
# -----------------------------------------
# sum:15      12.5         55         44.1
#average:x=3  y= 2.5       11         8.82

# 1. x= 3      y = 2.5      mean(x^2) = 11       mean(x*y) = 8.88

#value for the first week
# a1 = (8.88 - (3*2))/11-3^2 = 0.66
# a0 = 2.5-0.66*3 = 0.52
#y = 0.52+0.66*1 = 1.18

#value for the 2nd week
#y = 1.18*2 = 2.36

#value for the 3rd week
#y = 1.18*3 = 3.54

#value for the 4th week
#y = 1.18*4 = 4.72

#value for the 5th week
#y = 1.18*5 = 5.9

# %%
## loading liner_regr_salary_dataset file

import pandas as pd
data = pd.read_csv("/content/Linear_regr_Salary_dataset.csv")
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
## printing the size of the csv file

data.shape
# Out:
# (30, 3)

# %%
## checking  there are any null values in the dataframe

data.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
## storing values in the x and y variables

x = data[['YearsExperience']]
y = data[['Salary']]

# %%
## training

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4, random_state=58)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#     YearsExperience
# 12              4.1
# 26              9.6
# 27              9.7
# 19              6.1
# 2               1.6
# 10              4.0
# 6               3.1
# 28             10.4
# 5               3.0
# 1               1.4
# 20              6.9
# 29             10.6
# 21              7.2
# 14              4.6
# 25              9.1
# 23              8.3
# 0               1.2
# 3               2.1

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[ 65202.97736453],
#        [ 77154.89276419],
#        [ 75316.13654886],
#        [ 57847.95250321],
#        [ 66122.3554722 ],
#        [ 73477.38033353],
#        [101058.7235635 ],
#        [ 82671.16141018],
#        [ 62444.84304154],
#        [108413.74842482],
#        [ 57847.95250321],
#        [ 48654.17142655]])

# %%
## printing the size of the y_pred variable
y_pred.shape
# Out:
# (12, 1)

# %%
## printing the column values of the y_test
y_test
# Out:
#       Salary
# 11   55795.0
# 17   83089.0
# 16   66030.0
# 7    54446.0
# 13   57082.0
# 15   67939.0
# 22  101303.0
# 18   81364.0
# 9    57190.0
# 24  109432.0
# 8    64446.0
# 4    39892.0

# %%
## finding the accuarcy of the trained data

import numpy as np
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,np.round(y_pred))
accuracy
# Out:
# 0.0

# %%
## finding the prediction value of the column of the dataframe
inputdata = [[4.5]]
prediction = model.predict(inputdata)
np.round(y_pred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 65203.],
#        [ 77155.],
#        [ 75316.],
#        [ 57848.],
#        [ 66122.],
#        [ 73477.],
#        [101059.],
#        [ 82671.],
#        [ 62445.],
#        [108414.],
#        [ 57848.],
#        [ 48654.]])

# %%
## finding the mean_squared_error value

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 40388282.98898294

# %%
## printing the linear mean plot

import seaborn as sns
sns.lmplot(x='YearsExperience',y='Salary',data = data)

# %%
import matplotlib.pyplot as plt

sns.lmplot(x='YearsExperience',y='Salary',data = data)

ax = plt.gca()

plt.gca().set_facecolor('black')

# %%
sns.lmplot(x='YearsExperience',y='Salary',data = data,scatter_kws={'color':'skyblue'},line_kws={'color':'orange'})
sns.set_style('darkgrid')
ax = plt.gca()

plt.gca().set_facecolor('black')

# %%
## loading lr_student_performance file

df = pd.read_csv("/content/LR_Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
## finding the size of the above dataframe

df.shape
# Out:
# (10000, 6)

# %%
## printing the list of columns of the above dataframe

print(list(df.columns))
# Out:
# ['Hours Studied', 'Previous Scores', 'Extracurricular Activities', 'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index']

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
## checkig if there any null values

df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
## or

df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
## To check duplicated values

Duplicate_rows = df.duplicated()
(df[Duplicate_rows].sum())
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
# printing the performance column of the dataframe
responce = df['Performance Index']
responce
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 9873, dtype: float64

# %%
##
responce.dtype
# Out:
# dtype('float64')

# %%
## plotting the graph between performance index and index

import matplotlib.pyplot as plt
plt.plot(responce.index,responce)
plt.xlabel('Index')
plt.ylabel('Performance Index')
# Out:
# Text(0, 0.5, 'Performance Index')

# %%
## plotting the jointplot graph

sns.jointplot(x=responce.index,y='Performance Index',data = df,kind='hex',color='pink')

# %%
## plotting the violin graph

sns.violinplot(responce,color='yellow')
# Out:
# <Axes: ylabel='Performance Index'>

# %%
## finding the maximum value of the performance index
m = (df['Performance Index']).max()
m
(df['Performance Index']==m).sum()
# Out:
# 100.0

# %%
## finding the minimmum value of the performance index

 (df['Performance Index']).min()
# Out:
# 10.0

# %%
## calculating how many maximum hours got studied

 (df['Hours Studied']).max()
# Out:
# 9

# %%
## ## calculating how many minimum hours got studied

 (df['Hours Studied']).min()
# Out:
# 1

# %%
## calculating the count of the students got studied according to hours

import pandas as pd
pd.DataFrame(df['Hours Studied']).value_counts()
# Out:
# Hours Studied
# 1                1133
# 6                1122
# 7                1118
# 3                1110
# 9                1099
# 2                1077
# 8                1074
# 4                1071
# 5                1069
# dtype: int64

# %%
## or

 (df['Hours Studied']).value_counts()
# Out:
# 1    1133
# 6    1122
# 7    1118
# 3    1110
# 9    1099
# 2    1077
# 8    1074
# 4    1071
# 5    1069
# Name: Hours Studied, dtype: int64

# %%
## or
(df['Hours Studied']).unique()
# Out:
# array([7, 4, 8, 5, 3, 6, 2, 1, 9])

# %%
## or

m= df['Hours Studied'].value_counts().to_dict()
# Out:
# {1: 1133,
#  6: 1122,
#  7: 1118,
#  3: 1110,
#  9: 1099,
#  2: 1077,
#  8: 1074,
#  4: 1071,
#  5: 1069}

# %%
#bar plot

import seaborn as sns
sns.histplot(df['Hours Studied'],color = 'black',kde= True)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
## barplot between hours studied and performance index

sns.barplot(x=df['Hours Studied'],y=df['Performance Index'])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
## boxplot between hours studied and performance index

sns.boxplot(x=df['Hours Studied'],y=df['Performance Index'])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
## lmplot between hours studied and performance index


sns.lmplot(x='Hours Studied',y='Performance Index',data=df,)

# %%
## jointplot between hours studied and performance index


sns.jointplot(x='Hours Studied',y='Performance Index',data=df,kind='hex',color= 'pink')

# %%
## countplot of extracurricular activities

sns.countplot(x='Extracurricular Activities',data=df)
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='count'>

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced
# ...

# %%
y
# Out:
#       Performance Index
# 0                  91.0
# 1                  65.0
# 2                  45.0
# 3                  36.0
# 4                  66.0
# ...                 ...
# 9995               23.0
# 9996               58.0
# 9997               74.0
# 9998               95.0
# 9999               64.0
#
# [9873 rows x 1 columns]

# %%
df['Extracurricular Activities'].replace({'Yes': 1, 'No': 0},inplace = True)
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# ...

# %%
x=df[['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
       'Sleep Hours', 'Sample Question Papers Practiced']]

# %%
y =df[['Performance Index']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state=56)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[54.79252165],
#        [63.36036724],
#        [50.73652775],
#        ...,
#        [45.25660085],
#        [90.14579692],
#        [39.33377511]])

# %%
import numpy as np
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,np.round(y_pred))
accuracy
# Out:
# 0.19139240506329114

# %%
inputdata = [[5, 87, 0, 7, 5]]
prediction = model.predict(inputdata)
prediction
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[73.11030794]])

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 4.167207697628792

# %%
## TO handle the linear regression there is an another way in machine learning
## Instead of linear regression use Ridge

from sklearn.linear_model import Ridge

clf = Ridge()
clf.fit(x_train,y_train)
# Out:
# Ridge()

# %%
y_pred = clf.predict(x_test)
y_pred
# Out:
# array([[54.79278418],
#        [63.3603828 ],
#        [50.73626607],
#        ...,
#        [45.25692356],
#        [90.14547979],
#        [39.33398938]])

# %%
import pandas as pd
df = pd.read_csv("/content/framingham.csv")
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
m=df.isnull().sum()
m
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df =df.fillna(m)
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0    53.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
x=df[['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
       'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
       'diaBP', 'BMI', 'heartRate', 'glucose']]

# %%
y=df[['TenYearCHD']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.4, random_state=56)
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([[0.11543476],
#        [0.11491766],
#        [0.07357854],
#        ...,
#        [0.24223214],
#        [0.28941982],
#        [0.09185967]])

# %%
import numpy as np
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,np.round(y_pred))
accuracy
# Out:
# 0.8449292452830188

# %%
inputdata = [[0,45,2.0,1,20,25,0,1,1,230,120,80,15,85,100]]
prediction = model.predict(inputdata)
prediction
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.25019919]])
